# %%
import numpy as np
import pandas as pd

df_peugot_1 = pd.read_csv("peugeot_207_01.csv", delimiter=';', decimal=',')
df_peugot_2 = pd.read_csv("peugeot_207_02.csv", delimiter=';', decimal=',')

df_corsa_1 = pd.read_csv("opel_corsa_01.csv", delimiter=';', decimal=',')
df_corsa_2 = pd.read_csv("opel_corsa_02.csv", delimiter=';', decimal=',')

# %%
df_peugot_1
# Out:
#       AltitudeVariation  VehicleSpeedInstantaneous  VehicleSpeedAverage  \
# 0                   NaN                        0.0                  NaN
# 1                   NaN                        0.0                  NaN
# 2                   NaN                        0.0                  NaN
# 3                   NaN                        0.0                  NaN
# 4                   NaN                        0.0                  NaN
# ...                 ...                        ...                  ...
# 8609          -0.500000                        0.0            26.114999
# 8610           0.000000                        0.0            25.395000
# 8611          -0.099998                        0.0            24.735000
# 8612           0.500000                        0.0            24.075000
# 8613           0.800003                        0.0            23.505000
#
#       VehicleSpeedVariance  VehicleSpeedVariation  LongitudinalAcceleration  \
# 0                      NaN                    NaN                    0.0418
# 1                      NaN                    NaN                    0.0713
# 2                      NaN                    NaN                    0.0952
# 3                      NaN                    NaN                    0.1136
# 4                      NaN                    NaN                    0.1274
# ...                    ...                    ...                       ...
# 8609            128.927056                    0.0                    2.1969
# 8610            135.011667                    0.0                    2.1127
# 8611            142.079260                    0.0                    2.0643
# 8612            148.260888                    0.0                    1.8881
# 8613            156.016751                    0.0                    1.8078
#
#       EngineLoad  EngineCoolantTemperature  ManifoldAbsolutePressure  \
# 0      36.470589                      28.0                     100.0
# 1      36.470589                      28.0                     100.0
# 2      36.470589                      29.0                     100.0
# 3      36.470589                      29.0                     100.0
# 4      36.470589                      29.0                     100.0
# ...          ...                       ...                       ...
# 8609   30.196079                      79.0                     103.0
# 8610   30.196079                      79.0                     103.0
# 8611   30.980392                      79.0                     103.0
# 8612   29.411766                      79.0                     103.0
# 8613   29.411766                      79.0                     103.0
#
#       EngineRPM  MassAirFlow  IntakeAirTemperature  VerticalAcceleration  \
# 0         802.5        10.30                  14.0                0.0118
# 1         802.5        10.30                  14.0               -0.0023
# 2         798.5        10.24                  14.0               -0.0135
# 3         798.5        10.24                  15.0               -0.0161
# 4         804.5        10.36                  15.0               -0.0160
# ...         ...          ...                   ...                   ...
# 8609      751.0         4.24                  30.0               -1.5839
# 8610      751.5         4.30                  31.0               -1.5508
# 8611      749.5         4.13                  31.0               -1.5224
# 8612      751.5         4.24                  31.0               -1.5938
# 8613      751.5         4.19                  31.0               -1.5502
#
#       FuelConsumptionAverage      roadSurface                 traffic  \
# 0                        NaN  SmoothCondition  LowCongestionCondition
# 1                        NaN  SmoothCondition  LowCongestionCondition
# 2                        NaN  SmoothCondition  LowCongestionCondition
# 3                        NaN  SmoothCondition  LowCongestionCondition
# 4                        NaN  SmoothCondition  LowCongestionCondition
# ...                      ...              ...                     ...
# 8609               14.492782  UnevenCondition  LowCongestionCondition
# 8610               14.492782  UnevenCondition  LowCongestionCondition
# 8611               14.492782  UnevenCondition  LowCongestionCondition
# 8612               14.492782  UnevenCondition  LowCongestionCondition
# 8613               14.492782  UnevenCondition  LowCongestionCondition
#
#        drivingStyle
# 0     EvenPaceStyle
# 1     EvenPaceStyle
# 2     EvenPaceStyle
# 3     EvenPaceStyle
# 4     EvenPaceStyle
# ...             ...
# 8609  EvenPaceStyle
# 8610  EvenPaceStyle
# 8611  EvenPaceStyle
# 8612  EvenPaceStyle
# 8613  EvenPaceStyle
#
# [8614 rows x 17 columns]
